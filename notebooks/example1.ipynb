# %% [markdown]
# Example of stochastic bisection, the basic technique for calculating credible balls

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append("../src")
import numpy as np
import matplotlib.pyplot as plt

# %%
def fbase(x,a,b):
    return a*(1-x) + b*x
a = 0.6
b = -0.2
f = lambda x : fbase(x,a,b)
true_root = -a/(b-a)
def measurebase(x,f,noise):
    return f(x)+noise*np.random.randn()

measure = lambda x : measurebase(x,f,0.1)

# %%
import stochastic_bisection

# %%
stochastic_bisection.stochastic_bisection(measure,maxiter=1000,maxdrift=1000,verbose=1,tol=1e-6)
# Out:
# 0.5037037037037038 0.5370370370370371
# 0.5104663923182442 0.5713305898491085
# 0.5197281410354113 0.6030838794899153
# 0.5310038342920476 0.6324850736017734
# 0.5438742910111551 0.6597084014831236
# 0.5579783805658844 0.6849151865584477
# 0.5730060227461893 0.7082548023689331
# 0.5886919762464715 0.7298655577490122
# 0.6048103302652514 0.7498755164342705
# 0.6211696228344921 0.7684032559576579
# 0.634177454709458 0.7512479415841515
# 0.6440436635763267 0.7328395433781455
# 0.654646428041215 0.7500713082252098
# 0.6657671394997718 0.7658535426267841
# 0.6742984337179053 0.7510800816811062
# 0.6804091583444442 0.7354056799832936
# 0.6873897646136473 0.7502152210364759
# 0.6923017117149073 0.7365092356262469
# 0.6979997275816809 0.7492818703826435
# 0.7044540378440262 0.7625428302051327
# 0.7118649039377556 0.7785626987813201
# 0.7170279180915736 0.7634950454759358
# 0.7204093368517047 0.7508421056928845
# 0.722304995235795 0.7393659206926082
# 0.7223783762176773 0.7230388050546178
# ...
